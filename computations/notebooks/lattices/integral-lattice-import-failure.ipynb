# %%
L = IntegralLattice(Matrix(ZZ, 2, [1,0,0,1]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 L = IntegralLattice(Matrix(ZZ, Integer(2), [Integer(1),Integer(0),Integer(0),Integer(1)]))
#
# File ~/gitclones/sage/src/sage/modules/free_quadratic_module_integer_symmetric.py:254, in IntegralLattice(data, names, normalize, basis)
#      89 r"""
#      90 Return the integral lattice spanned by ``basis`` in the ambient space.
#      91
#    (...)
#     251     ValueError: lattices must be nondegenerate; use FreeQuadraticModule instead
#     252 """
#     253 # Import the refactored class - avoid circular import
# --> 254 from sage.modules.integral_lattice.lattice_class import FreeQuadraticModule_integer_symmetric
#     256 lattice_name = None
#     257 if is_Matrix(data):
#
# ModuleNotFoundError: No module named 'sage.modules.integral_lattice.lattice_class'

# %%
# ?IntegralLattice
# Out:
# Signature:      IntegralLattice(data, names=None, normalize=True, basis=None)
# Docstring:
#    Return the integral lattice spanned by "basis" in the ambient
#    space.
#
#    A lattice is a finitely generated free abelian group L \cong \ZZ^r
#    equipped with a non-degenerate, symmetric bilinear form L x L
#    : --> \ZZ. Here, lattices have an ambient quadratic
#    space \QQ^n and a distinguished basis.
#
#    INPUT:
#
#    The input is a descriptor of the lattice and a (optional) basis. -
#    "data" -- can be one of the following:
#
#       * a symmetric matrix over the rationals -- the inner product
#         matrix
#
#       * an integer -- the dimension for an Euclidean lattice
#
#       * a symmetric Cartan type or anything recognized by
#         "CartanMatrix" (see also "Cartan types") -- for a root lattice
#
#       * the string ""U"" or ""H"" -- for hyperbolic lattices
#
#    * "basis" -- (optional) a matrix whose rows form a basis of the
# ...

# %%
Z2 = ZZ.localization(2)
Z2
