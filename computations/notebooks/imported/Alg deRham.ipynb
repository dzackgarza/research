# %%
# %display latex
# macaulay2_console()

# loadPackage "Dmodules"
# R = QQ[x, y]
# f = y^3-x^2
# r = deRhamAll f
# r#CohomologyGroups

# %% [markdown]
# $$
# \begin{align*}
# H^*(\AA^n) &= k[0] \\
# H^*(\PP^n) &= k[0] \oplus \bigoplus_{\substack{ i=1 \\ \text{even} } }^n k[i]
# \end{align*}
# $$

# %%
macaulay2.eval("""
loadPackage "Dmodules";
R = QQ[x];
f = ;
r = deRhamAll f;
r#CohomologyGroups;
""")
# Out:
# gitclones/M2/M2/Macaulay2/packages/Dmodules.m2:2:1:(3):[8]: error: package Dmodules not reloaded; try Reload => true

# %%
macaulay2('f')
# Out:
#  2
# x  - x

# %%
R = macaulay2('r#CohomologyGroups')
R
# Out:
#                  1
# HashTable{0 => QQ }
#                  2
#           1 => QQ
