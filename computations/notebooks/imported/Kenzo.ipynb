# %%
from sage.interfaces.kenzo import EilenbergMacLaneSpace
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-ef46eb377956> in <module>()
# ----> 1 from sage.interfaces.kenzo import EilenbergMacLaneSpace
#
# /home/zack/gitclones/sage/local/lib/python3.7/site-packages/sage/interfaces/kenzo.py in <module>()
#      45 # Loading and initialization of Kenzo
#      46 # Note that it will load kenzo.fas file from $SAGE_LOCAL/lib/ecl/
# ---> 47 ecl_eval("(require :kenzo)")
#      48 ecl_eval("(in-package :cat)")
#      49 ecl_eval("(setf *HOMOLOGY-VERBOSE* nil)")
#
# /home/zack/gitclones/sage/local/lib/python3.7/site-packages/sage/libs/ecl.pyx in sage.libs.ecl.ecl_eval (build/cythonized/sage/libs/ecl.c:10132)()
#    1323
#    1324 #convenience routine to more easily evaluate strings
# -> 1325 cpdef EclObject ecl_eval(str s):
#    1326     """
#    1327     Read and evaluate string in Lisp and return the result
#
# ...
