# %%
L = [random_matrix(GF(2),7,7).nullity() for i in sequence(0, 100)]
L

# %%
M.nullity()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-51e788afe6f2> in <module>
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas --user

# %%
histogram([random_matrix(GF(2),7,7).nullity() for i in sequence(0, 10000)])

# %%
histogram([random_matrix(GF(2),8,8).nullity() for i in sequence(0, 10000)])

# %%
histogram([random_matrix(GF(2),92,92).nullity() for i in sequence(0, 10000)])

# %%
import numpy  as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

matrix = np.array([
    [84., 80.76923077, 68.05555556, 56.57894737, 60.,
     44.7761194, 55.2238806, 39.0625, 27.41935484, 29.8245614],
    [82.44274809, 67.70833333, 63.75, 44.44444444, 47.76119403,
     33.33333333, 22.78481013, 19.23076923, 9.21052632, 2.63157895],
    [53.33333333, 61.76470588, 48.64864865, 34.61538462, 0.,
     16.66666667, 0., 0., 0., 0.],
    [48., 25., 0., 0., 0., 0., 0., 0., 0., 0. ]])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

xpos = [range(matrix.shape[0])]
ypos = [range(matrix.shape[1])]
xpos, ypos = np.meshgrid(xpos, ypos)
xpos = xpos.flatten('F')
ypos = ypos.flatten('F')
zpos = np.zeros_like(xpos)

dx = 0.5 * np.ones_like(zpos)
dy = dx.copy()
dz = matrix.flatten()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b', zsort='average')

plt.show()
# Out:
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|Figure(432x288)|$$

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/zack/gitclones/sage/local/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
# Out:
# <module 'matplotlib.pyplot' from '/home/zack/gitclones/sage/local/lib/python3.9/site-packages/matplotlib/pyplot.py'>
