# %%
P.<x, y> = QQ[]
P
# Out:
# Multivariate Polynomial Ring in x, y over Rational Field

# %%
I = Ideal(x^3-y^6, x*y-y^3)

# %%
I.radical()
# Out:
# Ideal (y^2 - x) of Multivariate Polynomial Ring in x, y over Rational Field

# %%
var(x)
# Out:
# x

# %%
n = gap(20062006); n
# Out:
# 20062006

# %%
QQ
E = EllipticCurve([0,2,3,4,5])
E
# Out:
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x^2 + 4*x + 5 over Rational Field
